# %% [markdown]
# ## 통계 기반 영화 추천(학습 없음 => 머신러닝 적용 x)

# %%
# 영화 데이터를 가져옴(csv 파일은 git에 업로드 안 함)
# 다음 링크에서 다운
# https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system/input?select=tmdb_5000_credits.csv

import pandas as pd

df1 = pd.read_csv('tmdb_5000_credits.csv')
df2 = pd.read_csv('tmdb_5000_movies.csv')

# %%
# df1과 df2를 합치려면 합칠 수 있는 공통 열이름이 필요
# df1과 movie_id를 id로 변경해서 합치려고 함
df1.columns = ['id', 'title', 'cast', 'crew']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # df1과 df2를 합치려면 합칠 수 있는 공통 열이름이 필요
#       2 # df1과 movie_id를 id로 변경해서 합치려고 함
# ----> 3 df1.columns = ['id', 'title', 'cast', 'crew']
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\pandas\core\generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
#     814 directly, e.g. `series.index = [1, 2, 3]`.
#     815 """
#     816 labels = ensure_index(labels)
# --> 817 self._mgr.set_axis(axis, labels)
#     818 self._clear_item_cache()
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 20 elements, new values have 4 elements

# %%
# df2 뒤에 df1을 이어붙여서 합침(df1의 title은 제외 : 중복)

# %%
# 영화 정보에 score는 열을 추가
# weighted_rating으로 계산된 값을 적용
# appy(함수) : 값을 적용할 때 함수를 가져옴
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 # 영화 정보에 score는 열을 추가
#       2 # weighted_rating으로 계산된 값을 적용
#       3 # appy(함수) : 값을 적용할 때 함수를 가져옴
# ----> 4 q_movies['score'] = q_movies.apply(weighted_rating, axis=1)
#
# NameError: name 'q_movies' is not defined

# %%
# score를 기준으로 내림차순 한 후 상위 10개를 추천(추천 영화)
q_movies = q_movies.sort_values(by='score', ascending=False)
q_movies[['title', 'vote_count', 'vote_average', 'score']].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # score를 기준으로 내림차순 한 후 상위 10개를 추천(추천 영화)
# ----> 2 q_movies = q_movies.sort_values(by='score', ascending=False)
#       3 q_movies[['title', 'vote_count', 'vote_average', 'score']].head(10)
#
# NameError: name 'q_movies' is not defined
