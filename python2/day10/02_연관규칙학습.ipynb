# %%
## 라이브러리 설치
# !pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 9.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 11.8 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.0 MB 12.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 10.8 MB/s  0:00:00
# ...
#
#   Attempting uninstall: scikit-learn
#
# ...
