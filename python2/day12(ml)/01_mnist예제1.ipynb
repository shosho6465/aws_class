# %%
# !pip install opencv-python

# %%
import os
# mnist 이미지를 저장할 폴더를 생성
os.makedirs('mnist_images', exist_ok=True)

# %%
# mnist에서 제공하는 숫자 이미지를 다운로드
from sklearn.datasets import fetch_openml

# 데이터 로그, 숫자 이미지를 훈련 6만, 테스트 1만을 제공
mnist = fetch_openml('mnist_784', version=1, as_frame=False)

# 독립, 종속 분리
X, y = mnist['data'], mnist['target']

# %%
# 이미지 다운로드 # 꼭 필요한 코드는 아님. 생략 가능함
# 우리가 학습하는 이미지가 어떤 형태의 이미지인지 확인하기 위해 받음
import numpy as np
import cv2
for i in range(1000):
	# X는 1차원으로 되어 있어서 바로 이미지로 바꾸면 점이 찍힌 선이 됨
	# 그래서 원본인 28X28로 돌리기 위해 reshape을 함
	image = X[i].reshape(28,28).astype(np.uint8)
	label = y[i]
	# 0폴더~ 9폴더까지 생김(단, 저장하는 데이터가 너무 적으면 몇몇 폴더는 없을 수도 있음)
	os.makedirs(f'mnist_images/{label}', exist_ok=True)
	# 이미지 생성
	cv2.imwrite(f'mnist_images/{label}/img_{i}.png', image)
print("이미지 다운로드 완료")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       3 for X_tmp, y_tmp in zip(X, y):
#       4 	# X는 1차원적으로 되어 있어서 바로 이미지로 바꾸면 점이 찍힌 선이 됨
#       5 	# 그래서 원본인 28X28로 돌리기 위해 reshape을 함
#       6 	image = X_tmp.reshape(28,28).astype(np.uint8)
# ----> 7 	label = y[i]
#       8 	# 0폴더 ~ 9폴더까지 생김(ㅏㄴ, 저장하는 데이터가 너무 적으면 몇몇 폴더는 없을 수도 있음)
#       9 	os.makedirs(f'mnist)images/{label}', exist_ok=True)
#
# NameError: name 'i' is not defined

# %%
X_full, y_full = X, y
# 이미지를 학습시키기 위한 데이터로 변환
# X : 1차행렬 리스트
# y : 1차행렬 리스트의 답
import glob
X, y = [], []

# 폴더별로 이미지들을 가져와서 X,y에 넣어주는 작업
# 폴더가 0폴더~9폴더이기 때문에 0부터 9까지 반복
for folder in range(10):
	# 폴더에 있는 이미지(.png)들을 가져와서 X, y에 넣어주는 작업
	file_path = f'mnist_images/{folder}/*.png'
	for file in glob.glob(file_path):
		img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)

		X.append(img.flatten())
		y.append(str(folder))
		
# 리스트를 numpy 리스트로 변환		
X, y = np.array(X), np.array(y)

# %%
# 훈련, 테스트 분리
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 훈련, 테스트 분리
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:2924, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2921 arrays = indexable(*arrays)
#    2923 n_samples = _num_samples(arrays[0])
# -> 2924 n_train, n_test = _validate_shuffle_split(
#    2925     n_samples, test_size, train_size, default_test_size=0.25
#    2926 )
#    2928 if shuffle is False:
#    2929     if stratify is not None:
#
# File c:\Users\hi6\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:2504, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2501 n_train, n_test = int(n_train), int(n_test)
#    2503 if n_train == 0:
# -> 2504     raise ValueError(
#    2505         "With n_samples={}, test_size={} and train_size={}, the "
#    2506         "resulting train set will be empty. Adjust any of the "
#    2507         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2508     )
#    2510 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from sklearn.svm import SVC

model = SVC(kernel='rbf', C=1.0)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from sklearn.svm import SVC
#       3 model = SVC(kernel='rbf', C=1.0)
# ----> 4 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
# 200개 데이터로 정확도 확인
model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.score(X_test, y_test)
#
# NameError: name 'model' is not defined

# %%
# 7만개 데이터를 훈련, 테스트로 분리
X_full_train, X_full_test, y_full_train, y_full_test = train_test_split(X_full, y_full, test_size=0.2)
# 학습
model2 = SVC(kernel='rbf', c=1.0)
model2.fit(X_full_train, y_full_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 7만개 데이터를 훈련, 테스트로 분리
# ----> 2 X_full_train, X_full_test, y_full_train, y_full_test = train_test_split(X_full, y_full, test_size=0.2)
#       3 # 학습
#       4 model2 = SVC(kernel='rbf', c=1.0)
#
# NameError: name 'train_test_split' is not defined

# %%
model2.score(X_full_test, y_full_test)

# %%
model2.score(X_test, y_test)
